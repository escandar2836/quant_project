# %%
import requests
from bs4 import BeautifulSoup

naver_url = "https://naver.com"
resp = requests.get(naver_url)

soup = BeautifulSoup(resp.text, 'html.parser')
top_list = soup.

for item in top_list:
    print(item.text)
# Out:
# 최근검색어
# 내 검색어
# 내 검색어 등록
# @txt@
# 삭제
# 내 검색어 해제
# @txt@
#
# 메일
#
#
# 카페
#
#
# 블로그
#
#
# 지식인
#
#
# 쇼핑
#
#
# 네이버페이
#
#
# 네이버TV
#
# 사전
# 뉴스
# 증권(금융)
# 부동산
# 지도
# 영화
# 뮤직
# 책
# 만화 / 웹툰
#
# 네이버뉴스
#
# 연예
#
# 스포츠
#
# 경제
# 이전 페이지
# 다음 페이지
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 종합/경제
# 방송/통신
# IT
# 영자지
# 스포츠/연예
# 매거진/전문지
# 지역
# 코로나19 위기 단계 '심각'
# 국내 지역별 현황
# 국가별 현황
# 팩트체크
# 정부 정례 브리핑
# 리빙
# 푸드
# 스포츠
# 자동차
# 패션뷰티
# 부모i
# 건강
# 웹툰
# 게임
# TV연예
# 뮤직
# 영화
# 책문화
# 함께N
# 여행+
# 디자인
# 경제M
# JOB&
# 과학
# 중국
# 비즈니스
# FARM
# 스쿨잼
# 공연전시
# 법률
# 동물공감
# 연애·결혼
# 테크
# 감성충전
# 그라폴리오
# 배경화면
# 콜라보레이션
# 후원
# 공식 블로그
#
#
#
#
#
#
#
#
# 너를 위한 무지개
# 침대보다 포근한 당신의 품
#
#
#
#
#
#
#
#
#
#
# 그동안 감성충전판을 사랑해 주셔서 감사합니다.
#
#
#
#
#
#
#
#
# 사랑의 요리사
#
#
#
#
#
#
#
#
# 하루가 달라지니
#
#
#
#
#
#
#
#
# 바다로 - 유화, 수국, 해녀, 제주도
#
#
#
#
#
#
#
#
# 짙푸른 초저녁, 마을의 작은 불빛
#
#
#
#
#
#
# ëìì
#
#
# 수채화 물감과 마커를 이용해 신비로운 그림 그리기
#
#
#
#
#
#
#
#
# #우리만의 비밀정원
#
#
#
#
#
#
# 상품 추천
#
#
# 모시 콜라주로 그리는 우리 삶의 이야기
#
#
#
#
#
#
# 공모전
#
#
# 더 많은 공모전을 확인하고 참여해보세요!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 네이버 해피빈
# 코로나19 긴급 지원
# 오늘 끼니 해결도,마스크도 걱정인 이웃들
#
#
#
#
#
#
#
#
# 온스테이지 2.0
# cotoba(코토바)
# 마음과 감정을 뒤흔드는매스록 밴드, 코토바
#
#
# 크리에이터
# 스몰비즈니스
# 비즈니스 · 광고
# 스토어 개설
# 지역업체 등록
# 네이버 개발자센터
# 오픈 API
# 오픈소스
# 네이버 D2
# 네이버 D2SF
# 네이버 랩스
# 회사소개
# 인재채용
# 제휴제안
# 이용약관
# 개인정보처리방침
# 청소년보호정책
# 네이버 정책
# 고객센터
